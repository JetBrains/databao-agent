# %% [markdown]
# ## DataFrame

# %%
import portus
s = portus.open_session("a")
import pandas as pd
s.add_df(pd.DataFrame({"k": ["re", "tr", "yt"], "num": [1,2,3]}))
pipe = s.ask("What is sum of all values?")
print(pipe.text)

# %%
pipe.df

# %% [markdown]
# ## Database

# %%
import portus
s = portus.open_session("a")
import sqlalchemy as sa
url = "postgresql://Konstantin.Barzilovich@localhost:5432/sampledb"
engine = sa.create_engine(url, pool_pre_ping=True)

s.add_db(engine, name="sampledb")
pipe = s.ask("What is overall revenue?")
print(pipe.text)
# Out:
# Definitions and approach:
# - Overall revenue: total sales amount across all time in the system.
# - Revenue per order is computed as quantity * price, where price is per unit.
# Method: Summed quantity * price across all rows in sampledb.public.orders. Used COALESCE to return 0.00 if there are no orders.
# Result: The total (overall) revenue is 2023.94.

# %%
pipe.df
# Out:
#    overall_revenue
# 0          2023.94

# %%
pipe.sql
# Out:
# 'SELECT COALESCE(CAST(SUM(quantity * price) AS DECIMAL(18,2)), CAST(0 AS DECIMAL(18,2))) AS overall_revenue\nFROM sampledb.public.orders;'
